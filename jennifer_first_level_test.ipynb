# %%
from first_level_pipeline import main

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main()
#
# File ~/private/fmriWorkingMemoryProject/first_level_pipeline.py:95, in main()
#      93 for task in taskType:
#      94     for run in num_runs:
# ---> 95         beta_weights = extract_beta_weights(run, subject_id=subjID, task_type=task)
#      97         #save beta weights
#      98         save_beta(beta_weights, subjID, task, run)
#
# File ~/private/fmriWorkingMemoryProject/first_level_pipeline.py:48, in extract_beta_weights(num_run, subject_id, task_type)
#      45 events_path = f"~/teams/a05/group_1_data/fmriprep/events/sub-{subject_id}_task-{task_type}_acq-multiband_run-{num_run}_events.tsv"
#      47 #load subject nii files
# ---> 48 run_img = image.load_img(preproc_path)
#      50 #load the event file for the run
#      51 events = pd.read_csv(events_path, sep="\t",
# ...
