# %%
from pipeline_sahana_subjects import main

# %%
main()
# Out:
# Extracting betas for Subject 176, Task colorwheel, Run 1
# DONE for Subject 176, Task colorwheel, Run 1
# Extracting betas for Subject 176, Task colorwheel, Run 2
# DONE for Subject 176, Task colorwheel, Run 2
# Extracting betas for Subject 176, Task colorwheel, Run 3
# DONE for Subject 176, Task colorwheel, Run 3
# Extracting betas for Subject 176, Task colorwheel, Run 4
# DONE for Subject 176, Task colorwheel, Run 4
# Extracting betas for Subject 176, Task samedifferent, Run 1
# DONE for Subject 176, Task samedifferent, Run 1
# Extracting betas for Subject 176, Task samedifferent, Run 2
# DONE for Subject 176, Task samedifferent, Run 2
# Extracting betas for Subject 176, Task samedifferent, Run 3
# DONE for Subject 176, Task samedifferent, Run 3
# Extracting betas for Subject 176, Task samedifferent, Run 4
# DONE for Subject 176, Task samedifferent, Run 4
# Extracting betas for Subject 177, Task colorwheel, Run 1
# DONE for Subject 177, Task colorwheel, Run 1
# ...
